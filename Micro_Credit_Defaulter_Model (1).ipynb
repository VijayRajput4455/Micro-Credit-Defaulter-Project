# %%
# Importing Required libraies
import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline 

import scipy.stats as stats
import warnings 
warnings.filterwarnings('ignore')

# %%
# Loading the data into variable data using pandas read csv funtion.
data=pd.read_csv(r'G:\Intershop_21\FlipRobo Project\New folder\Micro Credit Project\Data file.csv')

# %%
# pandas set_option is used to display maximum columm or Row 
pd.set_option('display.max_columns', None)

# %%
data.head()     # Checking the first five rows of the data.
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 0    220.13    260.13                2.0                0.0              1539
# 1   3691.26   3691.26               20.0                0.0              5787
# 2    900.13    900.13                3.0                0.0              1539
# 3    159.42    159.42               41.0                0.0               947
# 4   1098.90   1098.90                4.0                0.0              2309
#
#    cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %%
data.tail()     # Checking the last five rows of the data.
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  \
# 209588   1089.19   1089.19                1.0                0.0
# 209589   1728.36   1728.36                4.0                0.0
# 209590   5861.83   8893.20                3.0                0.0
# 209591    411.83    984.58                2.0               38.0
# 209592    483.92    631.20               13.0                0.0
#
#         last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  \
# ...

# %%
data.sample(5)     # Checking the random five rows of the data.
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 105881      105882      1  41771I82737   254.0  14221.967333      14291.51
# 79563        79564      1  12349I88650   932.0  13298.622000      13412.22
# 88933        88934      1  90119I90586  1649.0  16485.063333      16533.19
# 106285      106286      1  34982I70375   712.0  13780.151000      13841.17
# 7958          7959      1  04575I70788   115.0   3894.000000       5186.50
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  \
# 105881  17385.71  19087.55                7.0                0.0
# 79563    1448.67   1878.51                6.0                0.0
# 88933    7151.57   9411.77               10.0                0.0
# 106285   3191.40   4188.69                7.0                0.0
# 7958     2252.56   5319.64                6.0                0.0
#
#         last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  \
# ...

# %%
data.shape     # Checkign the shape of the dataset number of columns and rows
# Out:
# (209593, 37)

# %%
data.info()     # data.info is used to check the information of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %% [markdown]
# Data is having 209593 Rows and 37 columns.
# Data is not having any null values.
# Out of 36 columns 21 are float, 13 are integer and 3 are object type data.

# %%
data.dtypes
# Out:
# Unnamed: 0                int64
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# ...

# %%
data['Date_N']=pd.to_datetime(data['pdate'])     #Changing pdate to datetime format and making new clumn

# %%
data.dtypes
# Out:
# Unnamed: 0                       int64
# label                            int64
# msisdn                          object
# aon                            float64
# daily_decr30                   float64
# daily_decr90                   float64
# rental30                       float64
# rental90                       float64
# last_rech_date_ma              float64
# last_rech_date_da              float64
# last_rech_amt_ma                 int64
# cnt_ma_rech30                    int64
# fr_ma_rech30                   float64
# sumamnt_ma_rech30              float64
# medianamnt_ma_rech30           float64
# medianmarechprebal30           float64
# cnt_ma_rech90                    int64
# fr_ma_rech90                     int64
# sumamnt_ma_rech90                int64
# medianamnt_ma_rech90           float64
# medianmarechprebal90           float64
# cnt_da_rech30                  float64
# fr_da_rech30                   float64
# cnt_da_rech90                    int64
# ...

# %%
data.isnull().sum()     # Checking Any null values present in the data
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %%
sns.heatmap(data.isnull())     # Checking null values are present in dataset or not with the help of Seaborn(heatmap).
# Out:
# <AxesSubplot:>

# %% [markdown]
# Data is not having any null values.

# %%
data.describe()     # Lets see the descriptive statistics
# Out:
#           Unnamed: 0          label            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177    8112.343445    5381.402289
# std     60504.431823       0.330519   75696.082531    9220.623400
# min         1.000000       0.000000     -48.000000     -93.012667
# 25%     52399.000000       1.000000     246.000000      42.440000
# 50%    104797.000000       1.000000     527.000000    1469.175667
# 75%    157195.000000       1.000000     982.000000    7244.000000
# max    209593.000000       1.000000  999860.755168  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean     6082.515068    2692.581910    3483.406534        3755.847800
# std     10918.812767    4308.586781    5770.461279       53905.892230
# min       -93.012667  -23737.140000  -24720.580000         -29.000000
# ...

# %% [markdown]
# We can see data is having outliers and skewness.

# %%
data[data.duplicated()]     # Here we are checking whether the data is having duplicate value.
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, label, msisdn, aon, daily_decr30, daily_decr90, rental30, rental90, last_rech_date_ma, last_rech_date_da, last_rech_amt_ma, cnt_ma_rech30, fr_ma_rech30, sumamnt_ma_rech30, medianamnt_ma_rech30, medianmarechprebal30, cnt_ma_rech90, fr_ma_rech90, sumamnt_ma_rech90, medianamnt_ma_rech90, medianmarechprebal90, cnt_da_rech30, fr_da_rech30, cnt_da_rech90, fr_da_rech90, cnt_loans30, amnt_loans30, maxamnt_loans30, medianamnt_loans30, cnt_loans90, amnt_loans90, maxamnt_loans90, medianamnt_loans90, payback30, payback90, pcircle, pdate, Date_N]
# Index: []

# %% [markdown]
# ###### Data is not having any duplicate values.

# %%
# Lets analyse the label column 
data['label'].value_counts()/209593*100
# Out:
# 1    87.517713
# 0    12.482287
# Name: label, dtype: float64

# %%
# Lets analyse the label column
plt.figure(figsize=(8,6))
sns.countplot(data['label'])
plt.xlabel('whether the user paid back the credit amount')
plt.ylabel('Counts')

plt.show()

# %% [markdown]
# ##### Here we can see  87.50 percent of the user paid back the Credit Amount

# %% [markdown]
# #### Data is imbalanced, Before making model we will treat it.

# %%
data['Date_N'].dt.year.value_counts()
# Out:
# 2016    209593
# Name: Date_N, dtype: int64

# %% [markdown]
# Here we can see all the records are from 2016.

# %% [markdown]
# Before further moving we will drop the columns Unnamed: 0, msisdn and pdate.
# Unnamed :0 is index in our csv files, which is not having any impact in our data analysis process.
# msisdn is mobile numbers of the user , which also having no impact.
# For pdate we already created a datetime format column with name Date_N, so we can drop the pdate.

# %%
#Dropping the columns from data and storing new data in df variable. 
df= data.drop(['msisdn', 'Unnamed: 0','pdate'], axis=1 )

# %%
data['pcircle'].value_counts()
# Out:
# UPW    209593
# Name: pcircle, dtype: int64

# %% [markdown]
# All the users are using UPW as Telecome Circle. So we can drop this column also.

# %%
df.drop('pcircle', axis= 1, inplace= True)

# %%
df
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
#Lets plot the graphs and check the ditribution. 

for col in df.columns[:33]:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(df[col])
    plt.title(col)
    
    plt.subplot(122)
    stats.probplot(df[col], dist='norm', plot= plt)
    plt.title(col)
    
    plt.show()

# %% [markdown]
# From Q-Q plot and Dist plot we can observe that data is not normaly distributed.
# Data is highly positive skewed.
# For positve skewed data we can use log transformation which we apply later. lets first analyse the outliers.

# %% [markdown]
# #### Checking Outliers

# %%
for col in df.columns[:33]:
    plt.figure(figsize=(14,4))
    
    sns.boxplot(df[col])
    plt.title(col)

# %% [markdown]
# We can see data is having outliers

# %%
plt.figure(figsize=(10,7))
sns.countplot(data['maxamnt_loans90'], order=df['maxamnt_loans90'].value_counts().index)
plt.title('Maximum amount of loan taken by the user in last 90 days')
plt.show()

# %%
plt.figure(figsize=(18,7))
sns.countplot(data['cnt_ma_rech30'], order = df['cnt_ma_rech30'].value_counts().index)
plt.title('Number of times main account got recharged in last 30 days')
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.countplot(data['cnt_ma_rech90'], order = df['cnt_ma_rech90'].value_counts().index)
plt.title('Frequency of main account recharged in last 90 days')
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.countplot(data['cnt_loans30'], order = df['cnt_loans30'].value_counts().index)
plt.title('Number of loans taken by user in last 30 days')
plt.show()

# %%
sns.scatterplot(x='daily_decr30', y='aon', data= df, hue='label')
# Out:
# <AxesSubplot:xlabel='daily_decr30', ylabel='aon'>

# %%
df.head()
# Out:
#    label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  241.0     21.228000     21.228000    159.42    159.42
# 4      1  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0          21.0             3078.0                1539.0
# ...

# %%
collist=df.columns.values[0:33]
ncol= 9
nrows= 9

plt.figure(figsize=(2*ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows, ncol, i+1)
    sns.boxplot(y=df[collist[i]], color='green', orient='x')
    plt.tight_layout()

# %% [markdown]
# We can see data is having ouliers.

# %%
from scipy.stats import zscore

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 34 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   aon                   209593 non-null  float64
#  2   daily_decr30          209593 non-null  float64
#  3   daily_decr90          209593 non-null  float64
#  4   rental30              209593 non-null  float64
#  5   rental90              209593 non-null  float64
#  6   last_rech_date_ma     209593 non-null  float64
#  7   last_rech_date_da     209593 non-null  float64
#  8   last_rech_amt_ma      209593 non-null  int64
#  9   cnt_ma_rech30         209593 non-null  int64
#  10  fr_ma_rech30          209593 non-null  float64
#  11  sumamnt_ma_rech30     209593 non-null  float64
#  12  medianamnt_ma_rech30  209593 non-null  float64
#  13  medianmarechprebal30  209593 non-null  float64
# ...

# %%
df1=df.iloc[:,0:32]
df1
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
z=np.abs(zscore(df1))
z
# Out:
# array([[2.64789583, 0.10357685, 0.25229941, ..., 0.33421157, 0.22959366,
#         2.9046997 ],
#        [0.37765836, 0.09776412, 0.73103667, ..., 2.51768994, 0.22959366,
#         0.38562959],
#        [0.37765836, 0.10010243, 0.43201111, ..., 0.33421157, 0.22959366,
#         0.38562959],
#        ...,
#        [0.37765836, 0.09378769, 0.70079045, ..., 2.51768994, 0.22959366,
#         0.06820893],
#        [0.37765836, 0.08428915, 0.77075515, ..., 2.51768994, 0.22959366,
#         0.38562959],
#        [0.37765836, 0.08628398, 0.09674426, ..., 2.51768994, 0.22959366,
#         0.38562959]])

# %%
threshold = 3
print(np.where(z > 3))
# Out:
# (array([    21,     22,     30, ..., 209586, 209587, 209587], dtype=int64), array([15, 15,  6, ..., 28, 26, 30], dtype=int64))

# %%
data_new=df1[(z<3).all(axis=1)]
print(df1.shape)
print(data_new.shape)
# Out:
# (209593, 32)
# (162421, 32)

# %%
Loss_percentage=(209593-161465)/209593*100
print(Loss_percentage)
# Out:
# 22.962598941758554

# %%
data_new.shape
# Out:
# (162421, 32)

# %%
df1.head(2)
# Out:
#    label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  272.0       3055.05       3065.15    220.13    260.13
# 1      1  712.0      12122.00      12124.75   3691.26   3691.26
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0          21.0             3078.0                1539.0
# 1           0.0             5787.0                5787.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# ...

# %%
data_new.head(2)
# Out:
#    label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  272.0       3055.05       3065.15    220.13    260.13
# 1      1  712.0      12122.00      12124.75   3691.26   3691.26
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0          21.0             3078.0                1539.0
# 1           0.0             5787.0                5787.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# ...

# %%
data_new.head()
# Out:
#    label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  241.0     21.228000     21.228000    159.42    159.42
# 4      1  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0          21.0             3078.0                1539.0
# ...

# %%
y=data_new.iloc[:,0]
x=data_new.iloc[:,1:]

# %%
x.shape
# Out:
# (162421, 31)

# %%
x
# Out:
#            aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0        272.0   3055.050000   3065.150000    220.13    260.13
# 1        712.0  12122.000000  12124.750000   3691.26   3691.26
# 2        535.0   1398.000000   1398.000000    900.13    900.13
# 3        241.0     21.228000     21.228000    159.42    159.42
# 4        947.0    150.619333    150.619333   1098.90   1098.90
# ...        ...           ...           ...       ...       ...
# 209588   404.0    151.872333    151.872333   1089.19   1089.19
# 209589  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                     2.0                0.0              1539              2
# ...

# %%
y.shape
# Out:
# (162421,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
y
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 209588    1
# 209589    1
# 209590    1
# 209591    1
# 209592    1
# Name: label, Length: 162421, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

from sklearn.linear_model import LogisticRegression 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier 
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB

# %%
lr= LogisticRegression()
for i in range(0,10):
    x_train, x_test, y_train, y_test= train_test_split(x,y, random_state= i, test_size= 0.20)
    lr.fit(x_train, y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)== round(accuracy_score(y_test,pred_test)*100,1):
        print("At Random state ", i, "The Model performing Well")
        print("At Random State", i)
        print("Training Accuracy score is-",accuracy_score(y_train,pred_train)*100 )
        print("Testing Accuracy Score is-", accuracy_score(y_test,pred_test)*100)
# Out:
# At Random state  1 The Model performing Well
# At Random State 1
# Training Accuracy score is- 86.45410048023643
# Testing Accuracy Score is- 86.49838386947822
# At Random state  2 The Model performing Well
# At Random State 2
# Training Accuracy score is- 86.45256126092846
# Testing Accuracy Score is- 86.45528705556411

# %%
x_train_b, x_test_b, y_train_b, y_test_b= train_test_split(x,y,random_state=2,test_size=0.20)

# %%
lr.fit(x_train_b, y_train_b)
lr_pred=lr.predict(x_test_b)
print(accuracy_score(y_test_b,lr_pred))
# Out:
# 0.8645528705556411

# %%
from sklearn.metrics import classification_report 
print(classification_report(y_test_b, lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.10      0.16      4509
#            1       0.87      0.99      0.93     27976
#
#     accuracy                           0.86     32485
#    macro avg       0.72      0.54      0.55     32485
# weighted avg       0.83      0.86      0.82     32485

# %%
lr_pred=lr.predict(x_test_b)
from sklearn.model_selection import cross_val_score
lr_score=accuracy_score(y_test_b,lr_pred)
for j in range(2,10):
    lr_cv= cross_val_score(lr,x,y,cv=j)
    lr_cvscore=lr_cv.mean()
    print("at cv:-", j)
    print("Cross Validation scre is:-",lr_cvscore*100)
    print("Accuracy Score:-", lr_score*100)
    print("\n")
# Out:
# at cv:- 2
# Cross Validation scre is:- 86.44510270843449
# Accuracy Score:- 86.45528705556411
#
#
# at cv:- 3
# Cross Validation scre is:- 86.45249145717221
# Accuracy Score:- 86.45528705556411
#
#
# at cv:- 4
# Cross Validation scre is:- 86.44756571605974
# Accuracy Score:- 86.45528705556411
#
#
# at cv:- 5
# Cross Validation scre is:- 86.4457184893781
# Accuracy Score:- 86.45528705556411
#
#
# at cv:- 6
# Cross Validation scre is:- 86.45002848866311
# Accuracy Score:- 86.45528705556411
#
#
# at cv:- 7
# Cross Validation scre is:- 86.45002801361893
# Accuracy Score:- 86.45528705556411
#
#
# at cv:- 8
# Cross Validation scre is:- 86.44510386878278
# Accuracy Score:- 86.45528705556411
#
#
# at cv:- 9
# Cross Validation scre is:- 86.45187584291853
# Accuracy Score:- 86.45528705556411

# %%
lr_cv_selected= cross_val_score(lr,x,y,cv=8).mean()
print("The cross Val Score is: ",lr_cv_selected, "\n The Accuracy score is: ",lr_score)
# Out:
# The cross Val Score is:  0.8644510386878278
#  The Accuracy score is:  0.8645528705556411

# %%
svc=SVC()

# %%
from sklearn.neighbors import KNeighborsClassifier
kn=KNeighborsClassifier()

# %%
kn=KNeighborsClassifier(algorithm='auto', n_neighbors=10, weights='uniform')
kn.fit(x_train_b, y_train_b)
kn.score(x_train_b,y_train_b)
kn_pred=kn.predict(x_test_b)

kn_score= accuracy_score(y_test_b, kn_pred)
print('accuracy_score: 0', kn_score*100)

kncvscore=cross_val_score(kn,x,y, cv=8)
kncv_score=kncvscore.mean()
print('Cross val Score :',kncv_score*100 )
# Out:
# accuracy_score: 0 86.79698322302602
# Cross val Score : 86.9918309585448

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf=RandomForestClassifier(criterion='entropy', max_features='sqrt', n_estimators=30)
rf.fit(x_train_b, y_train_b)
rf.score(x_train_b,y_train_b)
rf_pred=rf.predict(x_test_b)

rf_score= accuracy_score(y_test_b, rf_pred)
print('accuracy_score: ', rf_score*100)

rfcvscore=cross_val_score(rf,x,y, cv=8)
rfcv_score=rfcvscore.mean()
print('Cross val Score :',rfcv_score*100 )
# Out:
# accuracy_score:  90.50330921963983
# Cross val Score : 90.569569772988

# %%
from sklearn.ensemble import AdaBoostClassifier
ad=AdaBoostClassifier()

# %%
ad=AdaBoostClassifier(algorithm='SAMME.R', learning_rate= 0.1, n_estimators= 40)
ad.fit(x_train_b, y_train_b)
ad.score(x_train_b,y_train_b)
ad_pred=ad.predict(x_test_b)

ad_score= accuracy_score(y_test_b, ad_pred)
print('accuracy_score: ', ad_score*100)

adcvscore=cross_val_score(ad,x,y, cv=8)
adcv_score=adcvscore.mean()
print('Cross val Score :',adcv_score*100 )
# Out:
# accuracy_score:  89.3951054332769
# Cross val Score : 89.37821962299243

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt=DecisionTreeClassifier(criterion='gini', max_features='sqrt', splitter= 'random')
dt.fit(x_train_b,y_train_b)
dt.score(x_train_b, y_train_b)
dt_pred=dt.predict(x_test_b)

dt_score= accuracy_score(y_test_b, dt_pred)
print("accuracy_score", dt_score*100)

dt_cv=cross_val_score(dt,x,y,cv=8)
dtcv_score= dt_cv.mean()
print("Cross val score is:",dtcv_score*100 )
# Out:
# accuracy_score 84.95921194397414
# Cross val score is: 85.07213164771036

# %%
from sklearn.naive_bayes import GaussianNB
gb=GaussianNB()
gb.fit(x_train_b, y_train_b)
gb.score(x_train_b, y_train_b)
gb_pred=gb.predict(x_test_b)

gb_score=accuracy_score(y_test_b, gb_pred)
print("Accuracy Score is:", gb_score*100)

gb_cv= cross_val_score(gb, x,y,cv=8)
gb_cvscore=gb_cv.mean()
print("Cross Val Score is :", gb_cvscore*100)
# Out:
# Accuracy Score is: 64.21117438817916
# Cross Val Score is : 64.12963905180521

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds= roc_curve(kn_pred, y_test_b)
roc_auc= auc(fpr, tpr)

plt.figure()
plt.plot(fpr,tpr, color='darkorange', lw=10,label='ROC curve (area= %0.2f)' %roc_auc)
plt.plot([0,1],[0,1],color ='navy', lw=10, linestyle= '--')
plt.xlim([0.0, 1.0])
plt.xlim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
import pickle
filename="Titanic_survive_sinking.pkl "
pickle.dump(kn, open(filename,'wb'))

# %%
import numpy as np
a=np.array(y_test_b)
predicted= np.array(kn.predict(x_test_b))
df_com= pd.DataFrame({'original':a, 'predicted':predicted}, index= range(len(a)))
df_com
# Out:
#        original  predicted
# 0             1          1
# 1             0          1
# 2             1          1
# 3             0          1
# 4             1          1
# ...         ...        ...
# 32480         1          1
# 32481         1          1
# 32482         1          1
# 32483         1          1
# 32484         1          1
#
# [32485 rows x 2 columns]
